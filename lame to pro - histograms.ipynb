# %% [markdown]
# # Check out my related post [here](https://open.substack.com/pub/datagroundup/p/matplotlib-histograms-from-lame-to?r=18swpa&utm_campaign=post&utm_medium=web&showWelcomeOnShare=true)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Top_650_FIFA.csv")

df

# https://www.kaggle.com/datasets/madhurpant/top-650-fifa-22-players-simplified
# Out:
#      Unnamed: 0         short_name                                 long_name  \
# 0             0           L. Messi            Lionel Andrés Messi Cuccittini
# 1             1     R. Lewandowski                        Robert Lewandowski
# 2             2  Cristiano Ronaldo       Cristiano Ronaldo dos Santos Aveiro
# 3             3          Neymar Jr             Neymar da Silva Santos Júnior
# 4             4       K. De Bruyne                           Kevin De Bruyne
# ..          ...                ...                                       ...
# 647         647         T. Malacia                            Tyrell Malacia
# 648         648      Wilson Manafá               Wilson Miguéis Manafá Jancó
# 649         649          J. Clauss                           Jonathan Clauss
# 650         650             Galeno  Wenderson Rodrigues do Nascimento Galeno
# 651         651       J. Lascelles                          Jamaal Lascelles
#
# ...

# %%
df.height_cm.hist()

plt.savefig("histogram0.png", bbox_inches="tight", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

numbin="auto"

n, bin_edges, patches = ax.hist(df.height_cm, bins=numbin, color="#1E315C", rwidth=0.98)

# ax.grid(False)
ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_linewidth(0.2)
ax.tick_params(which='both', width=0.2)

# Dynamic elements:

# the bin labels:
bin_centers = 0.5 * np.diff(bin_edges) + bin_edges[:-1]

labels = [f"< {bin_edges[1].astype(int)}"]  # The first label
labels += [f"{bin_edges[i].astype(int)+1} - {bin_edges[i + 1].astype(int)}" for i in range(1, len(bin_edges) - 2)]
labels += [f"{bin_edges[-2].astype(int)+1} +"] # The last label

ax.set_xticks(bin_centers, labels, rotation=45)

# The frequency labels:
for patches ,n in zip(patches, n): 
    height = patches.get_height() 
    ax.text(patches.get_x() + patches.get_width() / 2, height+.1, n.astype(int), 
            ha='center', va='bottom')

# Labels and title:

ax.set_ylabel('Number of players', loc='top')
ax.set_xlabel('Height of players (cm)', loc="left")
ax.set_title(f"Distribution of top {len(df.height_cm)} FIFA Player's Heights", loc="left", fontsize=14);

# %%
fig, ax = plt.subplots(figsize=(12, 6))

n, bin_edges, patches = ax.hist(df.height_cm, bins="auto", color="#1E315C", rwidth=0.98)

#plt.savefig("histogram1.png", bbox_inches="tight", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

n, bin_edges, patches = ax.hist(df.height_cm, bins="auto", color="#1E315C", rwidth=0.98)

ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_linewidth(0.2)
ax.tick_params(which='both', width=0.2)

ax.set_ylabel('Number of players', loc='top')
ax.set_xlabel('Height of players (cm)', loc="left")
ax.set_title(f"Distribution of top {len(df.height_cm)} FIFA Player's Heights", loc="left", fontsize=14)

#plt.savefig("histogram2.png", bbox_inches="tight", dpi=300)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

n, bin_edges, patches = ax.hist(df.height_cm, bins="auto", color="#1E315C", rwidth=0.98)

ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_linewidth(0.2)
ax.tick_params(which='both', width=0.2)

# Labels and title:

ax.set_ylabel('Number of players', loc='top')
ax.set_xlabel('Height of players (cm)', loc="left")
ax.set_title(f"Distribution of top {len(df.height_cm)} FIFA Player's Heights", loc="left", fontsize=14)

# the bin labels:
bin_centers = 0.5 * np.diff(bin_edges) + bin_edges[:-1]

labels = [f"< {bin_edges[1].astype(int)}"]  # The first label
labels += [f"{bin_edges[i].astype(int)+1} - {bin_edges[i + 1].astype(int)}" for i in range(1, len(bin_edges) - 2)]
labels += [f"{bin_edges[-2].astype(int)+1} +"] # The last label

ax.set_xticks(bin_centers, labels, rotation=45)

#plt.savefig("histogram3.png", bbox_inches="tight", dpi=300)

# %%
bin_edges
# Out:
# array([158.        , 160.26315789, 162.52631579, 164.78947368,
#        167.05263158, 169.31578947, 171.57894737, 173.84210526,
#        176.10526316, 178.36842105, 180.63157895, 182.89473684,
#        185.15789474, 187.42105263, 189.68421053, 191.94736842,
#        194.21052632, 196.47368421, 198.73684211, 201.        ])

# %%
fig, ax = plt.subplots(figsize=(12, 6))

numbin=10

n, bin_edges, patches = ax.hist(df.height_cm, bins=numbin, color="#1E315C", rwidth=0.98)

ax.spines[['top', 'right']].set_visible(False)
ax.spines[['left', 'bottom']].set_linewidth(0.2)
ax.tick_params(which='both', width=0.2)

# Labels and title:

ax.set_ylabel('Number of players', loc='top')
ax.set_xlabel('Height of players (cm)', loc="left")
ax.set_title(f"Distribution of top {len(df.height_cm)} FIFA Player's Heights - {numbin} bins" , loc="left", fontsize=14)

# the bin labels:
bin_centers = 0.5 * np.diff(bin_edges) + bin_edges[:-1]

labels = [f"< {bin_edges[1].astype(int)}"]  # The first label
labels += [f"{bin_edges[i].astype(int)+1} - {bin_edges[i + 1].astype(int)}" for i in range(1, len(bin_edges) - 2)]
labels += [f"{bin_edges[-2].astype(int)+1} +"] # The last label

ax.set_xticks(bin_centers, labels, rotation=45)

ax.bar_label(patches);

#plt.savefig("histogram6.png", bbox_inches="tight", dpi=300);
