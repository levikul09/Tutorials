# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Broadcasting

# %%
a = np.array([ [5,2,1] ])
b = np.array([ [4,8,4] ]).T

a+b
# Out:
# array([[ 9,  6,  5],
#        [13, 10,  9],
#        [ 9,  6,  5]])

# %% [markdown]
# # Scalars

# %%
s = 2

x = [5,2,1]

y=np.array(x)

# %%
s*x
# Out:
# [5, 2, 1, 5, 2, 1]

# %%
a = np.array([5,2,1,3])
b = np.array([4,1,5,7])

np.dot(a,b)
# Out:
# 48

# %% [markdown]
# # Linear Weighted Combination

# %%
l1 = 2
l2 = 5
l3 = -2
v1 = np.array([1,5,4])
v2 = np.array([3,6,2])
v3 = np.array([8,3,9])
l1*v1 + l2*v2 + l3*v3
# Out:
# array([ 1, 34,  0])

# %% [markdown]
# # Matrices

# %%
M = np.array([[7,7,3,8],
             [5,3,7,2],
             [9,4,4,1]])

M
# Out:
# array([[7, 7, 3, 8],
#        [5, 3, 7, 2],
#        [9, 4, 4, 1]])

# %%
M[1,3]
# Out:
# 2

# %%
plt.imshow(M, cmap='BrBG');

# %%
# set random seed

np.random.seed(42)

# %%
np.random.seed(42)

A = np.random.randint(0, 10, (3, 4))

A
# Out:
# array([[6, 3, 7, 4],
#        [6, 9, 2, 6],
#        [7, 4, 3, 7]])

# %%
np.random.seed(8)

B= np.random.randint(1, 10, (3, 3))

B
# Out:
# array([[4, 5, 2],
#        [6, 9, 4],
#        [9, 1, 6]])

# %%
s=5

shifted = B+s*np.eye(len(B)).astype(int)

shifted
# Out:
# array([[ 9,  5,  2],
#        [ 6, 14,  4],
#        [ 9,  1, 11]])

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(shifted, cmap='viridis')

# Add the values into the squares
for i in range(len(shifted)):
    for j in range(len(shifted[0])):
        text = ax.text(j, i, shifted[i, j],
                       ha='center', va='center', color='w', fontsize=36)

ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# Display the plot
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(A, cmap='viridis')

# Add the values into the squares
for i in range(len(A)):
    for j in range(len(A[0])):
        text = ax.text(j, i, A[i, j],
                       ha='center', va='center', color='w')

ax.set_xlabel('Columns')
ax.set_ylabel('Rows')

# Display the plot
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(B, cmap='viridis')

# Add the values into the squares
for i in range(len(B)):
    for j in range(len(B[0])):
        text = ax.text(j, i, B[i, j],
                       ha='center', va='center', color='w', fontsize=36)

ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# Display the plot
plt.show()

# %%
# create a diagonal amtrix

D = np.diag([1,2,3])

D
# Out:
# array([[1, 0, 0],
#        [0, 2, 0],
#        [0, 0, 3]])

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(D, cmap='viridis')

# Add the values into the squares
for i in range(len(D)):
    for j in range(len(D[0])):
        text = ax.text(j, i, D[i, j],
                       ha='center', va='center', color='w', fontsize=36)

# remove axis labels
ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# %%
np.random.seed(15)

B= np.random.randint(1, 10, (3, 3))
    
Triu= np.triu(B)

# %%
np.random.seed(15)

B= np.random.randint(1, 10, (3, 3))
    
Tril= np.tril(B)

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(Triu, cmap='viridis')

# Add the values into the squares
for i in range(len(Triu)):
    for j in range(len(Triu[0])):
        text = ax.text(j, i, Triu[i, j],
                       ha='center', va='center', color='w', fontsize=36)

# remove axis labels
ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(Tril, cmap='viridis')

# Add the values into the squares
for i in range(len(Tril)):
    for j in range(len(Tril[0])):
        text = ax.text(j, i, Tril[i, j],
                       ha='center', va='center', color='w', fontsize=36)

# remove axis labels
ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# %%
eye= np.eye(3)

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(eye, cmap='viridis')

# Add the values into the squares
for i in range(len(eye)):
    for j in range(len(eye[0])):
        text = ax.text(j, i, eye[i, j],
                       ha='center', va='center', color='w', fontsize=36)

# remove axis labels
ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# %%
zeros = np.zeros([3,3])

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Show the A as an image
im = ax.imshow(zeros, cmap='viridis')

# Add the values into the squares
for i in range(len(zeros)):
    for j in range(len(zeros[0])):
        text = ax.text(j, i, zeros[i, j],
                       ha='center', va='center', color='w', fontsize=36)

# remove axis labels
ax.set_xticks([])
ax.set_yticks([])

fig.set_facecolor('none')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Creating a fake dataset

df = pd.DataFrame({
    'A': np.random.rand(100) * 10,
    'B': np.random.randn(100) * 5,
    'C': np.random.randn(100) * 10 + 5,
    'D': np.random.rand(100) * 50,
    'E': np.random.rand(100) * 25
})

# Adding some artificial correlation
df['F'] = df['A'] + np.random.randn(100)
df['G'] = df['D'] * 0.5 + np.random.randn(100) * 5

# Creating the correlation matrix
corr_matrix = df.corr()

# Visualizing the correlation matrix
plt.figure(figsize=(6, 6), facecolor='none')



sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", annot_kws={"size": 15})
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
np.random.seed(15)

B= np.random.randint(1, 10, (3, 3))

B,B.T, (B+B.T)/2
# Out:
# (array([[9, 6, 6],
#         [8, 1, 8],
#         [6, 7, 2]]),
#  array([[9, 8, 6],
#         [6, 1, 7],
#         [6, 8, 2]]),
#  array([[9. , 7. , 6. ],
#         [7. , 1. , 7.5],
#         [6. , 7.5, 2. ]]))
